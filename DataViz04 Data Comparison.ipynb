# %% [markdown]
# <a href="https://colab.research.google.com/github/weeraphon-hub/data_viz_2022/blob/main/DataViz04%20Data%20Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # เปรียบเทียบ ข้อมูล ด้วย coordinate plot

# %%
import pandas as pd

# %%
ex_df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
ex_df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sample_data = ex_df.groupby('Name').mean()
sample_data
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth
# Name
# Iris-setosa            5.006       3.418        1.464       0.244
# Iris-versicolor        5.936       2.770        4.260       1.326
# Iris-virginica         6.588       2.974        5.552       2.026

# %%
sample_data.iloc[0,:]
# Out:
# SepalLength    5.006
# SepalWidth     3.418
# PetalLength    1.464
# PetalWidth     0.244
# Name: Iris-setosa, dtype: float64

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^')

# %%
plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro-')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*-')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^-')

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')    
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^')

# %% [markdown]
# ## การใช้ plt.plot
# `plt.plot`(`พิกัดแกน X`, `พิกัดแกน Y`, `ลักษณะของ marker + เส้นเชื่อม`)
#
# marker -> 'cML'

# %%
plt.plot([1],[2],'ro')

# %%
plt.plot([1,2],[2,4],'ro')

# %%
plt.plot([1,2],[2,4],'ro-.')

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')    
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro',label='setosa')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*',label='versicolor')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^',label='virginica')
plt.legend()

# %%
ex_df.iloc[:,:-1].columns.tolist()
# Out:
# ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro',label='Setosa')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*',label='Versicolor')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^',label='Virginica')
plt.legend()
plt.xticks([1,2,3,4], ex_df.iloc[:,:-1].columns.tolist(), rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x7f66bfe63690>,
# ...
#  [Text(0, 0, 'SepalLength'),
#   Text(0, 0, 'SepalWidth'),
#   Text(0, 0, 'PetalLength'),
#   Text(0, 0, 'PetalWidth')])

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro',label='Setosa')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*',label='Versicolor')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^',label='Virginica')
plt.legend()
plt.xticks([1,2,3,4], ex_df.iloc[:,:-1].columns.tolist(), rotation='vertical')
plt.title('Features comparison between 3 different Iris flowers');

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro',label='Setosa')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*',label='Versicolor')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^',label='Virginica')

plt.legend()
plt.xticks([1,2,3,4], ex_df.iloc[:,:-1].columns.tolist(), rotation='vertical')
plt.title('Features comparison between 3 different Iris flowers')
plt.ylabel('size (cm)');

# %% [markdown]
# #Hw วาดรูป ก้อนเมฆ และ ฝน ด้วย plt.plot

# %%
#ขนาด
plt.subplots(figsize=(7, 7))

#ก้อนเมฆ
X = [88.65, 89.25, 89.75, 90.25, 90.75,
     91, 91.25, 91.75, 92.25, 92.75, 
     93, 94, 94.75, 95.25, 
     95.50, 96.25, 97, 97.15, 97.25, 96.85, 96.25, 95.50, 94.25,
     93.50, 92.75, 92.25, 91.75, 91.25, 
     91, 90.75, 90.25, 89.75, 89.25, 
     89, 88, 87, 86.25, 86.25, 86.50,
     87, 86, 85.80, 85.80, 86.25, 87, 88, 
     88.65]
Y = [88.65, 88.50, 88.25, 88.25, 88.50, 
     89, 88.50, 88.25, 88.25, 88.50, 
     89, 88.75, 88.85, 89.25, 
     89.50, 89.50, 89.75, 90, 90.50, 91, 91.50, 91.75, 91.50,
     91, 91.50, 91.75, 91.75, 91.50,
     91, 91.50, 91.75, 91.75, 91.50,
     91, 91.15, 91.05, 90.75, 90.50, 90.25,
     90, 89.5, 89.25, 88.75, 88.50, 88.25, 88.25,
     88.65]

plt.plot(X, Y, '-')

#ฝน
plt.plot([88,88.15], [88,87.10], 'c-.')
plt.plot([89.80,89.90], [87.75,87.25], 'c-.')
plt.plot([88.25,88.40], [86.80,85.80], 'c-.')
plt.plot([89.95,90.05], [87,86.20], 'c-.')
plt.plot([91.45,91.60], [88,87.10], 'c-.')
plt.plot([91.65,91.80], [86.80,85.80], 'c-.')
plt.plot([93.20,93.35], [87.75,87.25], 'c-.')
plt.plot([93.40,93.55], [87,86], 'c-.')
plt.plot([94.85,95], [88.25,87.10], 'c-.')
plt.plot([95.05,95.20], [86.80,85.80], 'c-.')

#ตัดเส้นแกน
plt.axis('off')
# Out:
# (85.22749999999999, 97.8225, 85.5025, 92.0475)

# %%
#ฝน
plt.subplots(figsize=(13, 13))
plt.plot([4.5,3.5],[2,5],'-.')
plt.plot([6.5,5.5],[1,4.5],'-.')
plt.plot([8.5,7.5],[1,3.5],'-.')
plt.plot([10.5,9.5],[1,4],'-.')
plt.plot([12,11],[2,5],'-.')


# ก้อนเมฆ
plt.plot([4.5,5,5.5,5,4.5,4,3.5,3,2.5,2.5,3,3.5,4,4.5,5],
         [7,6.5,6,6,6,6,6,6.5,7,7.5,8,8.5,8.5,8.5,8],'b-')
plt.plot([4.5,4,6,8,10,10.5,10,9.5],
         [8.5,10,12.5,12.5,11.5,9.5,8.5,8.5],'b-')
plt.plot([9,9.5,11,11,9,8,7.5],
         [8.5,8.5,7.5,6.5,5,5,5.5],'b-')
plt.plot([8.5,7.5,6,5.5],
         [6.5,5.5,5.5,6],'b-')
