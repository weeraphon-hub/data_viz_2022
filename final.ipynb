# %% [markdown]
# <a href="https://colab.research.google.com/github/weeraphon-hub/data_viz_2022/blob/main/final" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #เตรียมข้อมูล

# %%
import pandas as pd  #ทำงานกับข้อมูลลักษณะตาราง
import os  #จัดการไฟล์และ path

# %%
from google.colab import drive  #เชื่อม google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/Dataviz Final Exam'   #pathจะชี้ไปยังโฟล์เดอร์
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # ข้อมูลชุดที่ 1

# %%
data1 = os.path.join(path,'hospital_list.xlsx') #แล้วก็ชี้ไปที่ไฟล์
print(data1)
# Out:
# /content/drive/My Drive/Dataviz Final Exam/hospital_list.xlsx

# %%
data2 = pd.read_excel(data1)  #กำหนดตัวแปร data2 เป็นข้อมูล ไฟล์ hospital_list.xlsx
data2  #เรียกดูตารางของข้อมูล ไฟล์ hospital_list.xlsx
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %% [markdown]
# ## ตัดเอาเฉพาะคอลัมน์ที่ต้องการ

# %%
data3= data2[['hcode','name','zone_name','province','amphur','tambon','name5']]
data3
# Out:
#        hcode                                               name  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...                                                ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#                       zone_name         province            amphur     tambon  \
# 0            สาขาพื้นที่(ระยอง)      สมุทรปราการ  เมืองสมุทรปราการ     ปากน้ำ
# ...

# %% [markdown]
# ## ตรวจสอบค่า missing

# %%
data3.isnull().any()
# Out:
# hcode        False
# name          True
# zone_name     True
# province     False
# amphur        True
# tambon        True
# name5         True
# dtype: bool

# %% [markdown]
# ## แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data4

# %%
data4= data3.fillna(value={'name':'ไม่ทราบ','zone_name':'ไม่ทราบ','amphur':'ไม่ทราบ','tambon':'ไม่ทราบ','name5':'ไม่ทราบ'}) #แทน missing ด้วยค่าที่เหมาะสม จากตาราง data3
data4 # แสดงตาราง data4
# Out:
#        hcode                                               name  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง
# ...      ...                                                ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ
#
#                       zone_name         province            amphur     tambon  \
# 0            สาขาพื้นที่(ระยอง)      สมุทรปราการ  เมืองสมุทรปราการ     ปากน้ำ
# ...

# %% [markdown]
# ##ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
data4.isnull().any()
# Out:
# hcode        False
# name         False
# zone_name    False
# province     False
# amphur       False
# tambon       False
# name5        False
# dtype: bool

# %% [markdown]
# # ข้อมูลชุดที่ 2

# %%
data5 = os.path.join(path,'alldb.csv') #แล้วก็ชี้ไปที่ไฟล์
print(data5)
# Out:
# /content/drive/My Drive/Dataviz Final Exam/alldb.csv

# %%
data6 = pd.read_csv(data5)  #กำหนดตัวแปร data6 เป็นข้อมูล ไฟล์ alldb.csv
data6  #เรียกดูตารางของข้อมูล ไฟล์ alldb.csv
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# ...

# %% [markdown]
# ## ตัดเอาเฉพาะคอลัมน์ที่ต้องการ

# %%
data7= data6[['user','RowKey','date','phone','site','time','urine','ov','PartitionKey']]
data7
# Out:
#                 user                                    RowKey        date  \
# 0               test                                       NaN         NaN
# 1              04857      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png         NaN
# 3      3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...              ...                                       ...         ...
# 40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C         NaN
# 40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1         NaN
# 40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9         NaN
# 40033            NaN                            bbuogxulur.png         NaN
# 40034            NaN                            zttpqogiso.png         NaN
#
#                   phone   site      time            urine   ov  \
# ...

# %% [markdown]
# ## ตรวจสอบว่าข้อมูลมีค่า Missing หรือไม่

# %%
data7.isnull().any()  #ดูค่า Missing รายคอลัมน์ของตาราง data6
#เนื่องจากมี True แสดงว่ามีค่าที่เป็น Missing จะทำการลบค่า Missing ต่อไป
# Out:
# user            True
# RowKey          True
# date            True
# phone           True
# site            True
# time            True
# urine           True
# ov              True
# PartitionKey    True
# dtype: bool

# %% [markdown]
# ## เปลี่ยน Type Data จากข้อมูลที่เป็น string ให้เป็นค่าว่าง

# %%
data7['user'] = pd.to_numeric(data7['user'], errors='coerce')
data7['site'] = pd.to_numeric(data7['site'], errors='coerce')
data7['ov'] = pd.to_numeric(data7['ov'], errors='coerce')
data7['PartitionKey'] = pd.to_numeric(data7['PartitionKey'], errors='coerce')
data7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## เปลี่ยน Type Data จากข้อมูลที่เป็น numeric ให้เป็นค่าว่าง

# %%
data7['phone']=data7['phone'].astype('string')
data7['RowKey']=data7['RowKey'].astype('string')
data7['urine']=data7['urine'].astype('string')
data7
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## แทน missing ด้วยค่าที่เหมาะสม
#
# โดยคำสั่ง fillna() ของตาราง data8

# %%
data8= data7.fillna(value={'user':'00000','RowKey':'ไม่ระบุ','date':'0000-00-00','phone':'ไม่ระบุ','site':'00000','time':'00:00:00','urine':'ไม่ระบุ','PartitionKey':'00000'}) #แทน missing ด้วยค่าที่เหมาะสม จากตาราง data7
data8 # แสดงตาราง data8
# Out:
#                   user                                    RowKey        date  \
# 0                00000                                   ไม่ระบุ  0000-00-00
# 1               4857.0      136FD222-FD9F-4E54-AE1F-7282A276B085  2022-02-24
# 2                00000  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png  0000-00-00
# 3      3450101576642.0      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 4      3450101576642.0      45197AF7-7CB4-470C-9ABB-37C092BD6B21  2022-02-23
# ...                ...                                       ...         ...
# 40030            00000      6B5FA20F-190E-4021-8547-C12308024C6C  0000-00-00
# 40031            00000      F48C51C0-A345-40D6-93F4-46213267E1B1  0000-00-00
# 40032            00000      A986BDAA-6D7C-4017-8E62-A3C104E946B9  0000-00-00
# 40033            00000                            bbuogxulur.png  0000-00-00
# 40034            00000                            zttpqogiso.png  0000-00-00
#
# ...

# %%
data9 = data8.dropna() #ตัดข้อมูลที่เป็นค่าว่างของ ov ออก เพราะไม่สามารถแทนค่า missing ด้วยค่าอื่นได้ เนื่องจากต้องการข้อมูลที่เป็นตัวเลข 0-4 เท่านั้น
data9
# Out:
#                   user                                RowKey        date  \
# 3      3450101576642.0  2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE  2022-02-23
# 9      3450101576642.0  9AF8428C-0616-47DE-AB4C-54F31EA31979  2022-02-23
# 10     3450101576642.0  B7C1D24C-8090-4C2F-BC04-7CC4D09663DC  2022-02-23
# 13     3450101576642.0  C5E5C877-D7BC-4137-A328-8F350932B9DF  2022-02-23
# 14     3450101576642.0  D94E9A26-80AF-4A24-A4DC-A4F78414694C  2022-02-23
# ...                ...                                   ...         ...
# 40028            00000                        lkwfdvltek.png  0000-00-00
# 40029            00000                        txslrhofvq.png  0000-00-00
# 40031            00000  F48C51C0-A345-40D6-93F4-46213267E1B1  0000-00-00
# 40032            00000  A986BDAA-6D7C-4017-8E62-A3C104E946B9  0000-00-00
# 40034            00000                        zttpqogiso.png  0000-00-00
#
#                    phone    site      time            urine   ov PartitionKey
# ...

# %% [markdown]
# ##ตรวจสอบว่ายังมีค่า Missing หรือไม่

# %%
data9.isnull().any()
# Out:
# user            False
# RowKey          False
# date            False
# phone           False
# site            False
# time            False
# urine           False
# ov              False
# PartitionKey    False
# dtype: bool

# %% [markdown]
# ### User

# %%
data9.dtypes
# Out:
# user             object
# RowKey           string
# date             object
# phone            string
# site             object
# time             object
# urine            string
# ov              float64
# PartitionKey     object
# dtype: object

# %%
data9 = data9[(data9['user'].astype(str).str.isdigit()) & (data9['user'].str.len() == 5)] 
data9
# Out:
#         user                                RowKey        date  \
# 20     00000                        aczroqxlzp.png  2022-02-23
# 24     00000                        aqgzagjmut.png  2022-02-26
# 25     00000                        bauvbwzbtv.png  2022-02-26
# 26     00000                        bdvpqurtvu.png  2022-02-22
# 29     00000                        bhnsgchboh.png  2022-02-23
# ...      ...                                   ...         ...
# 40028  00000                        lkwfdvltek.png  0000-00-00
# 40029  00000                        txslrhofvq.png  0000-00-00
# 40031  00000  F48C51C0-A345-40D6-93F4-46213267E1B1  0000-00-00
# 40032  00000  A986BDAA-6D7C-4017-8E62-A3C104E946B9  0000-00-00
# 40034  00000                        zttpqogiso.png  0000-00-00
#
#                    phone    site      time            urine   ov PartitionKey
# 20      Samsung SM-A305F   00000  09:27:30  ปกติ (เหลืองใส)  0.0        00000
# ...

# %% [markdown]
# ### RowKey

# %% [markdown]
# ### date

# %% [markdown]
# ### phone

# %% [markdown]
# ### site

# %% [markdown]
# ### time

# %% [markdown]
# ### urine

# %% [markdown]
# ### ov

# %% [markdown]
# ### PartitionKey

# %% [markdown]
# ## รวมข้อมูลที่ 1 และข้อมูลที่ 2
